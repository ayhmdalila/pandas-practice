# %%
import pandas as pd
df = pd.read_csv("IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Groupby function & different aggregations

# %% [markdown]
# ## Min, max

# %%
df.groupby("species").aggregate("max")
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa               5.8          4.4           1.9          0.6
# Iris-versicolor           7.0          3.4           5.1          1.8
# Iris-virginica            7.9          3.8           6.9          2.5

# %%
df.groupby("species").aggregate("min")
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa               4.3          2.3           1.0          0.1
# Iris-versicolor           4.9          2.0           3.0          1.0
# Iris-virginica            4.9          2.2           4.5          1.4

# %% [markdown]
# ## Avg/mean

# %%
df.groupby("species").aggregate("mean")
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# ## Count

# %%
df.groupby("species").aggregate("count")
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %% [markdown]
# ## Sum

# %%
df.groupby("species").aggregate("sum")
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             250.3        170.9          73.2         12.2
# Iris-versicolor         296.8        138.5         213.0         66.3
# Iris-virginica          329.4        148.7         277.6        101.3

# %% [markdown]
# # Specifying aggregations per column

# %%
df.groupby("species").aggregate({"sepal_length": "mean"})
# Out:
#                  sepal_length
# species
# Iris-setosa             5.006
# Iris-versicolor         5.936
# Iris-virginica          6.588

# %%
df.groupby("species").aggregate({"sepal_length": "mean", "sepal_length": "max"})
# Out:
#                  sepal_length
# species
# Iris-setosa               5.8
# Iris-versicolor           7.0
# Iris-virginica            7.9

# %%
df.groupby("species").aggregate({"sepal_length": "mean", "petal_length": "max"})
# Out:
#                  sepal_length  petal_length
# species
# Iris-setosa             5.006           1.9
# Iris-versicolor         5.936           5.1
# Iris-virginica          6.588           6.9

# %%
df["petal_length"] = df["petal_length"] / 2

df.petal_length.map(lambda r: r/2)

df.petal_length.apply(lambda r: r/2)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Sorting

# %%
df.sort_values(by="sepal_length", ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# ..            ...          ...           ...          ...             ...
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
#
# [150 rows x 5 columns]

# %%
df.sort_values(by="sepal_length", ascending=True)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.sort_index()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.sort_values(by=["sepal_length", "sepal_width"], ascending=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# ..            ...          ...           ...          ...             ...
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.sepal_length.astype("string")

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
